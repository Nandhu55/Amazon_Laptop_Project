# %% [markdown]
# Import required libraries

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\nandishwar\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\nandishwar\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nandishwar\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nandishwar\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nandishwar\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nandishwar\anaconda3\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nandishwar\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\nandishwar\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Amazon URL

# %%
URL = "https://www.amazon.in/s?k=laptop&crid=3H4ZV8KKLMX73&sprefix=lapto%2Caps%2C348&ref=nb_sb_noss_2"

# %% [markdown]
# Make a header to mimic a browser visit (We make headers to tell that we are not any hackers or scammers)

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) "
"Chrome/144.0.0.0 Safari/537.36"}

# %% [markdown]
# Send request to URL

# %% [markdown]
# Beautifulsoup to parse the HTML Content (It helps to convert the scarp data to html form)

# %%
data = []
print("Data list cleared")

for page in range(1, 7):  
    params = {"k": "laptop", "page": page}
    
    # Use verify=False to bypass SSL verification (for testing purposes)
    response = requests.get(URL, params=params, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    
    products = soup.find_all("div", {"data-component-type": "s-search-result"})

    
    
    for product in products:
        # Extracting the product title
        title_tag = product.find("h2")
        if not title_tag:
            continue
        title_text = title_tag.get_text(strip=True)

        
        # Extracting the product price
        price_tag = product.find("span", {"class": "a-price-whole"})
        price_text = price_tag.get_text(strip=True) if price_tag else "N/A"

        #Extracting the processor
        processor = re.search(r"(i[3579]|Ryzen\s?\d)", title_text)
        processor = processor.group() if processor else None
        
        # Extracting the product brand
        match = re.match(r'^\W*([A-Za-z]+)', title_text)
        brand = match.group(1).upper() if match else "UNKNOWN"

        # Extracting RAM (improved version)
        ram_match = re.search(r'(\d+)\s*GB\s*(RAM|DDR\d+|LPDDR\d+)', title_text, re.IGNORECASE)
        ram = ram_match.group(1) + "GB" if ram_match else "N/A"
        
        # Extracting the product rating 
        rating_tag = product.find("span", class_="a-icon-alt")
        rating = "N/A"
        if rating_tag:
            rating_match = re.search(r'(\d+\.?\d*)', rating_tag.get_text())
            rating = rating_match.group(1) if rating_match else "N/A"

        # Extracting the Product SSD - Simplified
        ssd_match = re.search(r'(\d+)\s*(GB|TB)\s*(?:SSD|NVMe)', title_text, re.IGNORECASE) or re.search(r'(\d+)\s*(GB|TB)', title_text)
        ssd = (ssd_match.group(1) + ssd_match.group(2).upper()) if ssd_match else "N/A"
      

        # Extracting the Product Windows Version - Improved version
        windows_version = "N/A"
        
        # Try: "Windows 11", "Windows 10", "Win11", "Win10", etc.
        windows_match = re.search(r'(?:Windows\s*|Win\s*)(\d+)', title_text, re.IGNORECASE)
        if windows_match:
            windows_version = "Windows " + windows_match.group(1)
        
        # Extracting the Product Color
        color_match = re.search(r'\b(Black|Silver|Gray|Grey|White|Blue|Red|Gold|Green|Brown|Pink|Purple|Yellow|Orange|Champagne|Midnight|Space|Cosmic|Stardust|Graphite|Ash|Onyx|Platinum|Metallic)\b', title_text, re.IGNORECASE)
        color = color_match.group(1) if color_match else "N/A"

        # Extracting Discount Percentage
        discount_tag = product.find("span", string=re.compile(r'%'))
        discount = discount_tag.get_text(strip=True) if discount_tag else "N/A"

        screen_match = re.search(r'(\d{1,2}\.?\d?)\s*(?=[^\d]*cm|[^\d]*["\'])',title_text,re.IGNORECASE)
        screen_size = screen_match.group(1) if screen_match else "N/A"



        # Store the extracted data in a dictionary and append to the list
        data.append({
            "Title": title_text,
            "Price": price_text,
            "Processor":processor,
            "Brand": brand,
            'RAM': ram,
            "Rating": rating,
            "Storage": ssd,
            "Windows": windows_version,
            "Color": color,
            "Discount": discount,
            "Screen Size": screen_size
        })

      
    print(f"Page {page} scraped")
    time.sleep(1)
# Out:
# Data list cleared
# Page 1 scraped
# Page 2 scraped
# Page 3 scraped
# Page 4 scraped
# Page 5 scraped
# Page 6 scraped

# %%
for product in data:
    print("Title:", product["Title"])
    print("Price:", product["Price"])
    print("Brand:", product["Brand"])
    print("Processor:",product["Processor"])
    print("RAM:", product.get("RAM"))
    print("Rating:", product.get("Rating"))
    print("Storage:", product.get("Storage"))
    print("Windows:", product.get("Windows"))
    print("Color:", product.get("Color"))
    print("Discount:",product.get("Discount"))
    print("Screen Size:",product.get("screen_size"))
    print("-" * 50)
# Out:
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop
# Price: 60,490
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black
# Price: 10,990
# Brand: EBOOK
# Processor: None
# RAM: 4GB
# Rating: 5.0
# Storage: 4GB
# Windows: Windows 11
# Color: Black
# Discount: (56% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop
# Price: N/A
# Brand: HP
# Processor: Ryzen 3
# RAM: 8GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: N/A
# Screen Size: None
# --------------------------------------------------
# Title: BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey
# Price: 12,990
# Brand: BROWSEBOOK
# Processor: None
# RAM: 4GB
# Rating: 3.0
# Storage: 128GB
# Windows: Windows 11
# Color: Grey
# Discount: (57% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter
# Price: 40,654
# Brand: HP
# Processor: i3
# RAM: 12GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (25% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop
# Price: 41,990
# Brand: HP
# Processor: i3
# RAM: 12GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA
# Price: 15,990
# Brand: LENOVO
# Processor: None
# RAM: 4GB
# Rating: 3.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# Discount: (56% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop
# Price: 34,790
# Brand: ASUS
# Processor: Ryzen 3
# RAM: 8GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: MSI Raider 18, Intel Series 2 Core Ultra 9 285HX, 46cm UHD+ 120Hz Gaming Laptop (64GB/4TB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 5090, GDDR7 24GB/Core Black/3.6Kg) A2XWJG-253IN
# Price: 4,99,990
# Brand: MSI
# Processor: None
# RAM: N/A
# Rating: 3.0
# Storage: 4TB
# Windows: Windows 11
# Color: Black
# Discount: (11% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 13th Gen Core i5-13420H 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Top Metal Cover/Backlit Keyboard/1Yr ADP/Grey/1.6Kg), 83K100S3IN
# Price: 62,700
# Brand: LENOVO
# Processor: i5
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (24% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU
# Price: 67,990
# Brand: HP
# Processor: None
# RAM: 24GB
# Rating: 4.3
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4X RAM, 512GB SSD, HD, 15.6"/39.62cm, Windows 11 Home, Pure Silver, 1.5KG, A325-45, Thin and Light Laptop
# Price: 26,990
# Brand: ACER
# Processor: None
# RAM: 12GB
# Rating: 3.4
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (25% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Home Notebook (4 GB RAM DDR4/ 128 GB SSD/Numeric Touch Pad/Thin & Light Weight/Silver)
# Price: 12,990
# Brand: THOMSON
# Processor: None
# RAM: 4GB
# Rating: 3.0
# Storage: 128GB
# Windows: N/A
# Color: Silver
# Discount: (48% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Victus, AMD Ryzen 7 7445HS, 4GB RTX 2050, 16GB DDR5(Upgradable) 512GB SSD, FHD, 144Hz, 300 nits, IPS, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fb3123AX, Backlit, Gaming Laptop
# Price: 62,990
# Brand: HP
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (15% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook S16,14th Gen, Intel Core 5-210H,Metallic Design Laptop(Intel UHD iGPU/16GB RAM/512GB SSD/FHD+/16"/144Hz/Windows 11/M365 Basic(1Year)*/Office Home 2024/Silver/1.7Kg) S3607VA-RP114WS
# Price: 67,990
# Brand: ASUS
# Processor: None
# RAM: 16GB
# Rating: 4.4
# Storage: 512GB
# Windows: Windows 11
# Color: Metallic
# Discount: (1% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop
# Price: 28,690
# Brand: HP
# Processor: None
# RAM: N/A
# Rating: 3.4
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (5% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 12th Gen Intel Core i5-12450H 15.6 Inch (39.6cm) FHD Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office Home 2024/3months Game Pass/Arctic Grey/1.62Kg), 83ER00MCIN
# Price: 52,400
# Brand: LENOVO
# Processor: i5
# RAM: N/A
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (32% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Victus, 14th Gen Intel Core i5-14450HX, 6GB RTX 3050, 24GB DDR5, 512GB SSD, FHD, 144Hz, IPS, 300 nits, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2303tx, RGB Gaming Laptop
# Price: 80,490
# Brand: HP
# Processor: i5
# RAM: 24GB
# Rating: 3.8
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS TUF A15, AMD Ryzen 7 7445HS, Gaming Laptop(RTX 3050-4GB/75W TGP/32GB RAM/1TB SSD/FHD/15.6"/144Hz/Backlit Keyboard/48Whrs/Windows 11/Graphite Black/2.3 Kg) FA506NCG-HN250W
# Price: 82,990
# Brand: ASUS
# Processor: Ryzen 7
# RAM: 32GB
# Rating: 4.2
# Storage: 1TB
# Windows: Windows 11
# Color: Graphite
# Discount: (13% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN
# Price: 46,699
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: N/A
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (21% off)
# Screen Size: None
# --------------------------------------------------
# Title: Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 22,990
# Brand: PRIMEBOOK
# Processor: None
# RAM: 8GB
# Rating: 4.4
# Storage: 8GB
# Windows: N/A
# Color: Gray
# Discount: (34% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop
# Price: 66,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop
# Price: 69,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Smartchoice Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5050, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fa2309TX, RGB Gaming Laptop
# Price: 1,09,990
# Brand: HP
# Processor: i7
# RAM: 24GB
# Rating: 4.0
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue
# Price: 10,990
# Brand: JIOBOOK
# Processor: None
# RAM: 4GB
# Rating: 2.9
# Storage: 4GB
# Windows: N/A
# Color: Blue
# Discount: (56% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Zenbook 14,Intel Core Ultra 7 (Series 2), Intel Arc iGPU,32GB,1TB,3K OLED Touch Screen,14",Windows 11,M365 Basic (1Year)*,Office 2024,Ponder Blue,1.28 kg UX3405CA-PZ163WS, Thin & Light Laptop
# Price: 1,14,990
# Brand: ASUS
# Processor: None
# RAM: N/A
# Rating: 4.1
# Storage: 32GB
# Windows: Windows 11
# Color: Blue
# Discount: (28% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop
# Price: 76,990
# Brand: ACER
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 3.8
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (29% off)
# Screen Size: None
# --------------------------------------------------
# Title: Microsoft New Surface Pro (11th Edition) - Windows 11 Home Copilot + PC - 13” OLED PixelSense Touchscreen - Qualcomm Snapdragon X Elite (12 Core) - 32GB RAM - 1TB SSD - Platinum - ZID-00014
# Price: 2,43,990
# Brand: MICROSOFT
# Processor: None
# RAM: 32GB
# Rating: 2.9
# Storage: 1TB
# Windows: Windows 11
# Color: Platinum
# Discount: (2% off)
# Screen Size: None
# --------------------------------------------------
# Title: Acer Aspire Lite, AMD Ryzen 7-7730U, 16 GB RAM, 512 GB SSD, Full HD IPS,15.6"/39.62 cm, Windows 11 Home, MS Office, Steel Gray, 1.59 KG, AL15-41, Thin and Light Laptop
# Price: 46,990
# Brand: ACER
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (30% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP Pavilion x360, 13th Gen Intel Core i5-1335U (16GB DDR4, 1TB SSD) FHD, 14''/35.6 cm, Touchscreen 2-in-1, Win 11, Office 21, Silver, 1.51 kg, ek1010TU/1149tu, FPR, 5MP Camera, B&O, Backlit Laptop
# Price: 77,490
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 3.9
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (22% off)
# Screen Size: None
# --------------------------------------------------
# Title: Walker Best Student & Office Work Laptop|Thin & Light|15.6" 1920 * 1080 Resolution FHD IPS Display |8GB RAM,256 GB SSD|Intel Celeron Processor N4020 | Windows 11 Home |Silver
# Price: 16,990
# Brand: WALKER
# Processor: None
# RAM: 8GB
# Rating: 2.9
# Storage: 256GB
# Windows: Windows 11
# Color: Silver
# Discount: (58% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 13th Gen Core i5-13420H 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Top Metal Cover/Backlit Keyboard/1Yr ADP/Grey/1.6Kg), 83K100S3IN
# Price: 62,700
# Brand: LENOVO
# Processor: i5
# RAM: 16GB
# Rating: 4.3
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (24% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop
# Price: 60,490
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (12% off)
# Screen Size: None
# --------------------------------------------------
# Title: acer SmartChoice ALG, 13th Gen Intel Core i5-13420H, NVIDIA GeForce RTX 3050-6GB DDR6, 16GB RAM, 512GB SSD, FHD 15.6"/39.62 cm, 144Hz, Windows 11 Home, Steel Gray, 1.99 KG, AL15G-53,Gaming Laptop
# Price: 62,990
# Brand: ACER
# Processor: i5
# RAM: 6GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/Silver)
# Price: 14,990
# Brand: THOMSON
# Processor: None
# RAM: 8GB
# Rating: 3.0
# Storage: 256GB
# Windows: N/A
# Color: Silver
# Discount: (46% off)
# Screen Size: None
# --------------------------------------------------
# Title: ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 8GB RAM, 512GB SSD, FHD 14"(1920 x 1080), Windows 11, Office Home 2024, M365 Basic (1Year)*, Black, 1.38kg, E1404FA-EB2522WS, AMD Radeon iGPU Laptop
# Price: 37,576
# Brand: ASUS
# Processor: Ryzen 5
# RAM: 8GB
# Rating: 5.0
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (23% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop
# Price: 57,926
# Brand: DELL
# Processor: i5
# RAM: 16GB
# Rating: 3.7
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (26% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" HD Thin and Light Laptop (8GB/512GB SSD/Windows 11 Home/Office Home 2024/1 Year ADP Free/Grey/1.6Kg), 82R4011MIN
# Price: 38,390
# Brand: LENOVO
# Processor: Ryzen 5
# RAM: N/A
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (46% off)
# Screen Size: None
# --------------------------------------------------
# Title: MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN
# Price: 60,990
# Brand: MSI
# Processor: i5
# RAM: N/A
# Rating: 4.2
# Storage: 512GB
# Windows: Windows 11
# Color: Gray
# Discount: (27% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN
# Price: 44,990
# Brand: LENOVO
# Processor: i3
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (38% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu
# Price: 67,990
# Brand: HP
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU
# Price: 67,990
# Brand: HP
# Processor: None
# RAM: 24GB
# Rating: 4.3
# Storage: 1TB
# Windows: Windows 11
# Color: Silver
# Discount: (19% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP OmniBook 5 (Previously Pavilion) Intel 13th Gen Core i5 1334U (16GB LPDDR5X,512GB SSD) 2K,IPS, 300nits, 16''/40.6cm, Win11,M365 Basic(1yr),Office Home24, Silver,1.79kg, Camera w/Shutter, ba1008TU
# Price: 59,990
# Brand: HP
# Processor: i5
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (27% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core 3, 14th Gen-100U, 8GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, Dell 15, Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop
# Price: 39,990
# Brand: DELL
# Processor: None
# RAM: 8GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Black
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop
# Price: 66,990
# Brand: HP
# Processor: None
# RAM: 16GB
# Rating: 4.1
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (20% off)
# Screen Size: None
# --------------------------------------------------
# Title: HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu
# Price: 67,990
# Brand: HP
# Processor: i7
# RAM: 16GB
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Silver
# Discount: (16% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 14, Intel 14th Generation Intel Core 5, 16 GB:DDR5 RAM, 512GB, FHD+ 14"/35.56cm 300 Nits Display, Backlit Keyboard + FPR, Win 11, Office H&S 2024, Platinum Silver, 1.54Kg Thin & Light Laptop
# Price: 62,990
# Brand: DELL
# Processor: None
# RAM: N/A
# Rating: 3.9
# Storage: 16GB
# Windows: Windows 11
# Color: Platinum
# Discount: (25% off)
# Screen Size: None
# --------------------------------------------------
# Title: Dell 15, Intel Core i3 13th Gen -1305U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39
# Rating: 4.0
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: N/A
# Screen Size: None
# --------------------------------------------------
# Title: Dyazo Slim 15" to 15.6 Inch Laptop Sleeve, Laptop Cover Case with Handle & Accessories Pocket Universal Compatible for Dell, HP, Lenovo, Asus and All Other Notebook etc. (Grey)
# Price: 279
# Brand: DYAZO
# Processor: None
# RAM: N/A
# Rating: 4.3
# Storage: N/A
# Windows: N/A
# Color: Grey
# Discount: (72% off)
# Screen Size: None
# --------------------------------------------------
# Title: Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)
# Price: 22,990
# Brand: PRIMEBOOK
# Processor: None
# RAM: 8GB
# Rating: 4.4
# Storage: 8GB
# Windows: N/A
# Color: Gray
# Discount: (34% off)
# Screen Size: None
# --------------------------------------------------
# Title: Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB RAM/512GB SSD/Integrated AMD Radeon Graphics/Windows 11/Office Home 2024/Grey/1.6Kg), 82XM0114IN
# Price: 52,490
# Brand: LENOVO
# Processor: Ryzen 7
# RAM: 16GB
# Rating: 3.9
# Storage: 512GB
# Windows: Windows 11
# Color: Grey
# Discount: (28% off)
# Screen Size: None
# --------------------------------------------------

# %%
data
# Out:
# [{'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop",
#   'Price': '60,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'EBook 11.6" HD Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB DDR4 | 128GB eMMC + M.2 SSD Expandable Slot | Win 11 Home |31Wh Battery | UHD Graphics 600 | Black',
#   'Price': '10,990',
#   'Processor': None,
#   'Brand': 'EBOOK',
#   'RAM': '4GB',
#   'Rating': '5.0',
#   'Storage': '4GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(56% off)',
#   'Screen Size': '11.6'},
#  {'Title': "HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fc0500AU, FHD Camera w/Privacy Shutter Laptop",
#   'Price': 'N/A',
#   'Processor': 'Ryzen 3',
#   'Brand': 'HP',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': 'N/A',
#   'Screen Size': '15.6'},
#  {'Title': 'BrowseBook 14.1" FHD IPS Laptop | Best Student & Office Work Laptop | Celeron N4020 | 4GB RAM | 128GB SSD | Windows 11 | 38Wh | 1.3kg | Grey',
#   'Price': '12,990',
#   'Processor': None,
#   'Brand': 'BROWSEBOOK',
#   'RAM': '4GB',
#   'Rating': '3.0',
#   'Storage': '128GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(57% off)',
#   'Screen Size': '14.1'},
#  {'Title': "HP 15 Consumer Series Laptop, Intel Core i3-1315U (13th Gen) 12GB DDR4 RAM,512GB NVMe SSD/ 15.6'' FHD Anti-Glare, Micro-Edge, Win11, M365 Basic(1yr)* Office24, Silver,1.59kg, FHD Camera with Shutter",
#   'Price': '40,654',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': '12GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(25% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15, 13th Gen Intel Core i3-1315U (12GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, fd0573TU, FHD Camera w/Shutter Laptop",
#   'Price': '41,990',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': '12GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo {SmartChoice)Chromebook Intel Celeron N4500 (4GB RAM/64GB eMMC 5.1/11.6 Inch (29.46cm)/HD Display/2Wx2 Stereo Speakers/HD Camera/Chrome OS/Blue/1.21Kg), 82UY0014HA',
#   'Price': '15,990',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '4GB',
#   'Rating': '3.9',
#   'Storage': '4GB',
#   'Windows': 'N/A',
#   'Color': 'Blue',
#   'Discount': '(56% off)',
#   'Screen Size': '46'},
#  {'Title': 'ASUS Vivobook Go 14, AMD Ryzen 3 7320U, 8GB RAM, 512GB SSD, FHD 14", Windows 11, Office Home 2024, Mixed Black, 1.38 kg, E1404FA-NK3325WS, AMD Radeon iGPU, M365 Basic (1Year)*, Thin & Light Laptop',
#   'Price': '34,790',
#   'Processor': 'Ryzen 3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(21% off)',
#   'Screen Size': '14'},
#  {'Title': 'MSI Raider 18, Intel Series 2 Core Ultra 9 285HX, 46cm UHD+ 120Hz Gaming Laptop (64GB/4TB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 5090, GDDR7 24GB/Core Black/3.6Kg) A2XWJG-253IN',
#   'Price': '4,99,990',
#   'Processor': None,
#   'Brand': 'MSI',
#   'RAM': 'N/A',
#   'Rating': '3.0',
#   'Storage': '4TB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(11% off)',
#   'Screen Size': '46'},
#  {'Title': 'Lenovo IdeaPad Slim 3 13th Gen Core i5-13420H 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Top Metal Cover/Backlit Keyboard/1Yr ADP/Grey/1.6Kg), 83K100S3IN',
#   'Price': '62,700',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(24% off)',
#   'Screen Size': '38.8'},
#  {'Title': "HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU",
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer Aspire 3, Intel Core Celeron N4500, 12GB LPDDR4X RAM, 512GB SSD, HD, 15.6"/39.62cm, Windows 11 Home, Pure Silver, 1.5KG, A325-45, Thin and Light Laptop',
#   'Price': '26,990',
#   'Processor': None,
#   'Brand': 'ACER',
#   'RAM': '12GB',
#   'Rating': '3.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(25% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Home Notebook (4 GB RAM DDR4/ 128 GB SSD/Numeric Touch Pad/Thin & Light Weight/Silver)',
#   'Price': '12,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '4GB',
#   'Rating': '3.0',
#   'Storage': '128GB',
#   'Windows': 'N/A',
#   'Color': 'Silver',
#   'Discount': '(48% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP Victus, AMD Ryzen 7 7445HS, 4GB RTX 2050, 16GB DDR5(Upgradable) 512GB SSD, FHD, 144Hz, 300 nits, IPS, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fb3123AX, Backlit, Gaming Laptop",
#   'Price': '62,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(15% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook S16,14th Gen, Intel Core 5-210H,Metallic Design Laptop(Intel UHD iGPU/16GB RAM/512GB SSD/FHD+/16"/144Hz/Windows 11/M365 Basic(1Year)*/Office Home 2024/Silver/1.7Kg) S3607VA-RP114WS',
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Metallic',
#   'Discount': '(1% off)',
#   'Screen Size': '16'},
#  {'Title': 'HP 14s Intel Celeron Dual Core N4500 Laptop (8GB/512GB SSD/Win 11) 14.0" HD Display, MSO 24, Black, 1.46kg, DQ3149TU Thin and Light Business Laptop',
#   'Price': '28,690',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '3.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(5% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo IdeaPad Slim 3 12th Gen Intel Core i5-12450H 15.6 Inch (39.6cm) FHD Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office Home 2024/3months Game Pass/Arctic Grey/1.62Kg), 83ER00MCIN',
#   'Price': '52,400',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(32% off)',
#   'Screen Size': '39.6'},
#  {'Title': "HP Victus, 14th Gen Intel Core i5-14450HX, 6GB RTX 3050, 24GB DDR5, 512GB SSD, FHD, 144Hz, IPS, 300 nits, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2303tx, RGB Gaming Laptop",
#   'Price': '80,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS TUF A15, AMD Ryzen 7 7445HS, Gaming Laptop(RTX 3050-4GB/75W TGP/32GB RAM/1TB SSD/FHD/15.6"/144Hz/Backlit Keyboard/48Whrs/Windows 11/Graphite Black/2.3 Kg) FA506NCG-HN250W',
#   'Price': '82,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ASUS',
#   'RAM': '32GB',
#   'Rating': '4.2',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Graphite',
#   'Discount': '(13% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN',
#   'Price': '46,699',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)',
#   'Price': '22,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '8GB',
#   'Rating': '4.4',
#   'Storage': '8GB',
#   'Windows': 'N/A',
#   'Color': 'Gray',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '66,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': "HP Omnibook 5 OLED, Snapdragon X Processor (16GB LPDDR5x,1TB SSD) 2K OLED, Micro-Edge, 16''/40.6cm, Win11, M365*Office24, Glacier Silver, 1.59kg, fb0001QU, FHD Camera, Backlit, Next-Gen AI Laptop",
#   'Price': '69,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '16'},
#  {'Title': "HP Smartchoice Victus, 13th Gen Intel Core i7-13620H, 8GB RTX 5050, 24GB DDR5(Upgradeable) 1TB SSD, 144Hz, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.29kg, fa2309TX, RGB Gaming Laptop",
#   'Price': '1,09,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'JioBook 11 with Lifetime Office | Android 4G Laptop Mediatek 8788 (JioOS) | Octa-core | 4GB RAM | 64 eMMC Storage | Thin and Light Laptop (11.6 inch, 990 Grams) | Dual Band WiFi + SIM | Blue',
#   'Price': '10,990',
#   'Processor': None,
#   'Brand': 'JIOBOOK',
#   'RAM': '4GB',
#   'Rating': '2.9',
#   'Storage': '4GB',
#   'Windows': 'N/A',
#   'Color': 'Blue',
#   'Discount': '(56% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'ASUS Zenbook 14,Intel Core Ultra 7 (Series 2), Intel Arc iGPU,32GB,1TB,3K OLED Touch Screen,14",Windows 11,M365 Basic (1Year)*,Office 2024,Ponder Blue,1.28 kg UX3405CA-PZ163WS, Thin & Light Laptop',
#   'Price': '1,14,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': 'N/A',
#   'Rating': '4.1',
#   'Storage': '32GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(28% off)',
#   'Screen Size': '14'},
#  {'Title': 'acer Nitro V 15, AMD Ryzen 7-7445HS, NVIDIA GeForce RTX 4050-6 GB, 16GB DDR5, 512GB SSD, FHD IPS, 15.6"/39.62cm, 165Hz, Win 11 Home, Obsidian Black, 2.1KG, ANV15-42, Gaming Laptop',
#   'Price': '76,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(29% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Microsoft New Surface Pro (11th Edition) - Windows 11 Home Copilot + PC - 13” OLED PixelSense Touchscreen - Qualcomm Snapdragon X Elite (12 Core) - 32GB RAM - 1TB SSD - Platinum - ZID-00014',
#   'Price': '2,43,990',
#   'Processor': None,
#   'Brand': 'MICROSOFT',
#   'RAM': '32GB',
#   'Rating': '2.9',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(2% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Acer Aspire Lite, AMD Ryzen 7-7730U, 16 GB RAM, 512 GB SSD, Full HD IPS,15.6"/39.62 cm, Windows 11 Home, MS Office, Steel Gray, 1.59 KG, AL15-41, Thin and Light Laptop',
#   'Price': '46,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(30% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Pavilion x360, 13th Gen Intel Core i5-1335U (16GB DDR4, 1TB SSD) FHD, 14''/35.6 cm, Touchscreen 2-in-1, Win 11, Office 21, Silver, 1.51 kg, ek1010TU/1149tu, FPR, 5MP Camera, B&O, Backlit Laptop",
#   'Price': '77,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(22% off)',
#   'Screen Size': '14'},
#  {'Title': 'Walker Best Student & Office Work Laptop|Thin & Light|15.6" 1920 * 1080 Resolution FHD IPS Display |8GB RAM,256 GB SSD|Intel Celeron Processor N4020 | Windows 11 Home |Silver',
#   'Price': '16,990',
#   'Processor': None,
#   'Brand': 'WALKER',
#   'RAM': '8GB',
#   'Rating': '2.9',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(58% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 3 13th Gen Core i5-13420H 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Top Metal Cover/Backlit Keyboard/1Yr ADP/Grey/1.6Kg), 83K100S3IN',
#   'Price': '62,700',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(24% off)',
#   'Screen Size': '38.8'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop",
#   'Price': '60,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer SmartChoice ALG, 13th Gen Intel Core i5-13420H, NVIDIA GeForce RTX 3050-6GB DDR6, 16GB RAM, 512GB SSD, FHD 15.6"/39.62 cm, 144Hz, Windows 11 Home, Steel Gray, 1.99 KG, AL15G-53,Gaming Laptop',
#   'Price': '62,990',
#   'Processor': 'i5',
#   'Brand': 'ACER',
#   'RAM': '6GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Thomson NEO 14.1 Inch IN-P14C Intel Celeron Dual Core N4020 Processor & Window 11 Notebook (8 GB RAM DDR4/ 256 GB SSD/Numeric Touch Pad/1MP Webcam/Silver)',
#   'Price': '14,990',
#   'Processor': None,
#   'Brand': 'THOMSON',
#   'RAM': '8GB',
#   'Rating': '3.0',
#   'Storage': '256GB',
#   'Windows': 'N/A',
#   'Color': 'Silver',
#   'Discount': '(46% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'ASUS Vivobook Go 14, AMD Ryzen 5 7520U, 8GB RAM, 512GB SSD, FHD 14"(1920 x 1080), Windows 11, Office Home 2024, M365 Basic (1Year)*, Black, 1.38kg, E1404FA-EB2522WS, AMD Radeon iGPU Laptop',
#   'Price': '37,576',
#   'Processor': 'Ryzen 5',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(23% off)',
#   'Screen Size': '14'},
#  {'Title': 'Dell 15, Intel Core i5 13th Gen-1334U, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, Windows 11, MSO 2024, Silver, 1.62kg, [Dell 15], Backlit Keyboard, 15 Month McAfee, Thin & Light, Laptop',
#   'Price': '57,926',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.7',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 1 AMD Ryzen 5 5500U 15.6" HD Thin and Light Laptop (8GB/512GB SSD/Windows 11 Home/Office Home 2024/1 Year ADP Free/Grey/1.6Kg), 82R4011MIN',
#   'Price': '38,390',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(46% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'MSI Thin 15, Intel 13th Gen. Core i5-13420H, 40CM FHD 144Hz Gaming Laptop(16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050,GDDR6 4GB/Cosmos Gray/1.86Kg), B13UC-1805IN',
#   'Price': '60,990',
#   'Processor': 'i5',
#   'Brand': 'MSI',
#   'RAM': 'N/A',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(27% off)',
#   'Screen Size': '40'},
#  {'Title': 'Lenovo V15 Intel Core i3 13th Gen (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey) 15.6" FHD (1920x1080) Antiglare 250 Nits Thin & Light Laptop/1Y Onsite/1.65 kg, 83CCA08KIN',
#   'Price': '44,990',
#   'Processor': 'i3',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(38% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu',
#   'Price': '67,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(16% off)',
#   'Screen Size': '39.6'},
#  {'Title': "HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU",
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 5 (Previously Pavilion) Intel 13th Gen Core i5 1334U (16GB LPDDR5X,512GB SSD) 2K,IPS, 300nits, 16''/40.6cm, Win11,M365 Basic(1yr),Office Home24, Silver,1.79kg, Camera w/Shutter, ba1008TU",
#   'Price': '59,990',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(27% off)',
#   'Screen Size': '16'},
#  {'Title': 'Dell 15, Intel Core 3, 14th Gen-100U, 8GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, Dell 15, Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '39,990',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '66,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': 'HP 15, 13th Gen Intel Core i7-1355U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, 15.6’’/39.6cm, Win11, M365(1yr)* Office 24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter, Backlit Laptop fd0468tu/fd0515tu',
#   'Price': '67,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(16% off)',
#   'Screen Size': '39.6'},
#  {'Title': 'Dell 14, Intel 14th Generation Intel Core 5, 16 GB:DDR5 RAM, 512GB, FHD+ 14"/35.56cm 300 Nits Display, Backlit Keyboard + FPR, Win 11, Office H&S 2024, Platinum Silver, 1.54Kg Thin & Light Laptop',
#   'Price': '62,990',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': 'N/A',
#   'Rating': '3.9',
#   'Storage': '16GB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(25% off)',
#   'Screen Size': '14'},
#  {'Title': 'Dell 15, Intel Core i3 13th Gen -1305U, 16GB DDR4, 512GB SSD, FHD, 15.6"/39.6cm, Windows 11, Office H&S 2024, Carbon Grey, 1.66Kg, [Vostro 3530], Intel UHD Graphics, Narrow Border, Thin & Light Laptop',
#   'Price': '40,990',
#   'Processor': 'i3',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(25% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 3, 12th Gen Intel Core i5-12450H (16GB LPDDR5, 512GB SSD), Anti-glare, FHD 15.6"(39.6cm), Win 11, Office Home 2024, Arctic Grey, 1.62Kg, 83ER00MDIN, Thin & Light, Backlit KB Laptop',
#   'Price': '51,985',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(38% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '66,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': 'ASUS Vivobook 15, Smartchoice, AMD Ryzen 7 5825U, 16GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Quiet Blue, 1.7Kg, M1502YA-BQ703WS, AMD Radeon iGPU, M365 Basic (1Year)*, 42Whr Laptop',
#   'Price': '48,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'DELL 14 (2026) Intel Core 3 14th Gen 100U - (16 GB DDR5/512 GB SSD/Intel UHD Graphics/Windows 11 Home) Thin and Light Business Laptop/14.0" FHD+ IPS Display/Ice Blue/1.4 kg/MSO 2021',
#   'Price': '43,850',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(6% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo Yoga Slim 7 (Smartchoice) Intel Core Ultra 9 185H 14"(35.5cm) WUXGA-OLED Laptop (32GB RAM/1TB SSD/AI PC/Windows 11/Microsoft 365 Basic + Office Home 2024/1Yr ADP Free/Grey/1.39Kg), 83CV00B3IN',
#   'Price': '1,09,990',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '32GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(30% off)',
#   'Screen Size': '14'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop",
#   'Price': '60,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ULTIMUS APEX Laptop Intel Pentium Quad Core 8 GB DDR3 512 GB SSD Expandable~1TB 14.1 HD IPS Laptop Anti-Glare Ultra Thin Bezel 180° Hinge 3.0x3 USB HDMI SD Card Slot Win 11 Home 1.25KG Silver',
#   'Price': '18,990',
#   'Processor': None,
#   'Brand': 'ULTIMUS',
#   'RAM': '8GB',
#   'Rating': '3.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(53% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP Smartchoice Victus, 13th Gen i7-13620H, 6GB RTX 4050, 16GB DDR4(Upgradeable) 512GB SSD, 144Hz, 300nits, FHD, 15.6''/39.6cm, Win11, M365* Office24, Mica Silver, 2.3kg, fa2100/03/04tx, Gaming Laptop",
#   'Price': '92,990',
#   'Processor': 'i7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(8% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-1335U (16GB DDR4,512GB SSD) FHD, Anti-Glare,Micro-Edge, 15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver,1.59kg, fd0467tu, Iris Xe, FHD Camera w/Shutter, Backlit Laptop",
#   'Price': '54,990',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo LOQ, AMD Ryzen 5 7235HS, RTX 3050-6GB, 24GB RAM, 512GB SSD, FHD, 15.6"/39.6cm, 144Hz, Windows 11, Office Home 2024, Grey, 2.4Kg, 3 Mon. Game Pass, 83JC00EFIN, Gaming Laptop',
#   'Price': '76,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'MSI Katana 15, Intel 14th Gen. i7-14650HX, 40CM QHD 165Hz Gaming Laptop (16GB/512GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 5050, GDDR7 8GB/Black/2.4Kg) B14WEK-266IN',
#   'Price': '1,14,990',
#   'Processor': 'i7',
#   'Brand': 'MSI',
#   'RAM': 'N/A',
#   'Rating': '4.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(11% off)',
#   'Screen Size': '40'},
#  {'Title': "HP Laptop 15, Intel Core i5-1335U-13th Gen, (16GB DDR4,512GB SSD) Anti-Glare, Micro-Edge, FHD, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.59kg, Iris Xe, FHD Camera w/Shutter",
#   'Price': '55,990',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(22% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Portable Touchscreen, 15.6" 1080P 60Hz Laptop Monitor, Lightweight Dual USB C HDMI Second Gaminig Display with Speakers, Travel Monitor for PS4/5 Xbox Switch MAC PC Phone',
#   'Price': '16,999',
#   'Processor': None,
#   'Brand': 'PORTABLE',
#   'RAM': 'N/A',
#   'Rating': '4.1',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(26% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'DELL 14 (2026) Intel Core 3 14th Gen 100U - (8 GB DDR5/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" FHD+ IPS Display/Ice Blue/1.4 kg/MSO 2021',
#   'Price': '38,350',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '8GB',
#   'Rating': 'N/A',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(41% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo IdeaPad Slim 3 13th Gen Core i5-13420H 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Top Metal Cover/Backlit Keyboard/1Yr ADP/Grey/1.6Kg), 83K100S3IN',
#   'Price': '62,700',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(24% off)',
#   'Screen Size': '38.8'},
#  {'Title': "HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU",
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '66,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': 'Lenovo IdeaPad Slim 3 13th Gen Core i5-13420H 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Top Metal Cover/Backlit Keyboard/1Yr ADP/Grey/1.6Kg), 83K100S3IN',
#   'Price': '62,700',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(24% off)',
#   'Screen Size': '38.8'},
#  {'Title': 'Lenovo LOQ AMD Ryzen 5 7235HS | NVIDIA RTX 4050 6GB (16GB RAM/512GB SSD/144Hz Refresh Rate/15.6" (39.6cm)/Windows 11/Office Home 2024/3 Mon. Game Pass/Grey/2.4Kg), 83JC00NYIN AI Gaming Laptop',
#   'Price': '79,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.3',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Gaming V16 (2025) 14th Gen,Intel Core 7 240H Gaming Laptop (RTX 4050-6GB/16GB RAM/512GB SSD/Windows 11 Home/16/144Hz/M365*/Office Home 2024, Matte Black,1.95 Kg),V3607VU-RP275WS',
#   'Price': '92,990',
#   'Processor': None,
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(18% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Lenovo IdeaPad Slim 3 AMD Ryzen 7 8840HS 15.3 inch (38.8cm) WUXGA IPS Laptop (16GB RAM/512GB SSD/Windows 11/Office Home 2024/Backlit Keyboard/1Yr ADP Free/Grey/1.6Kg), 83KA004SIN',
#   'Price': '67,490',
#   'Processor': 'Ryzen 7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(29% off)',
#   'Screen Size': '38.8'},
#  {'Title': 'ASUS TUF A16 (2025), AMD Ryzen 7 7445HS, Gaming Laptop (RTX 4050-6GB/140W TGP/16GB RAM/1TB SSD/FHD+/16"/144Hz/56Whrs/Windows 11/M365 Basic (1Year)*/Office Home 2024/Mecha Gray/2.2Kg) FA607NUG-RL189WS',
#   'Price': '89,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(22% off)',
#   'Screen Size': '16'},
#  {'Title': 'ASUS Vivobook 15 (2025), 13th Gen,Intel Core i3-1315U, 8GB RAM, 512GB SSD, FHD, 15.6", 39.6 cm, Windows 11 Home,M365 Basic(1 Year)* Office 2024,Cool Silver,1.7 Kg, X1504VA-D5321WS, Thin & Light Laptop',
#   'Price': '38,974',
#   'Processor': 'i3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(24% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Cable World® Educational Laptop Computer Toy for Kids Above 3 Years - 20 Fun Activity Learning Machine, Now Learn Letter, Words, Games, Mathematics, Music, Logic, Memory Tool',
#   'Price': '699',
#   'Processor': None,
#   'Brand': 'CABLE',
#   'RAM': 'N/A',
#   'Rating': '3.8',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(73% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dell SmartChoice G15-5530, Intel Core i5 13th Gen-13450HX, NVIDIA RTX 3050-6GB, 16GB RAM, 1TB SSD, FHD, 15.6"/39.62cm, 120Hz, Windows 11, MS Office 24, Dark Shadow Grey, 2.65Kg, Gaming Laptop',
#   'Price': '79,990',
#   'Processor': 'i5',
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(24% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15, Intel Core Ultra 5 125H (24GB DDR5, 1TB SSD), Micro-Edge, Anti-Glare, FHD, 15''/39.6cm, Win11, M365* Office24, Silver, 1.65kg, FD1458TU, FHD Camera, Backlit Laptop",
#   'Price': '75,490',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(7% off)',
#   'Screen Size': '15'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop",
#   'Price': '60,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU",
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Wembley Educational Laptop for Kids Toys for 2-5 Years Learning Activity Computer Educational Toy for 3 Years Old Boy Learn Alphabet,Letter,Words,Games,Mathematics,Music,Logic Memory Tool,Multicolour',
#   'Price': '839',
#   'Processor': None,
#   'Brand': 'WEMBLEY',
#   'RAM': 'N/A',
#   'Rating': '3.9',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(56% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'HP Professional 14 (2025), Intel Core i3 13th Gen 1315U - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" HD Display/Turbo Silver/1.4 Kg/MSO 2021',
#   'Price': 'N/A',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '5.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': 'N/A',
#   'Screen Size': '14.0'},
#  {'Title': 'SAMSUNG Galaxy Book4 Edge Laptop 15.6" FHD Anti-Glare Qualcomm 8-core Snapdragon X (Up to 45 Tops) 16GB RAM 512GB SSD for Creator Designer Business Professional Win11 ICP Hub w/Copilot+ AI',
#   'Price': '58,490',
#   'Processor': None,
#   'Brand': 'SAMSUNG',
#   'RAM': '16GB',
#   'Rating': '4.4',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(37% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 3 13th Gen Core i7-13620H 15.3" (38.8cm) WUXGA IPS Laptop (24GB RAM/1TB SSD/Win 11/Office 2024/Backlit/1Yr ADP Free/Top Metal Cover & IR Camera/Grey/1.6Kg),83K100TEIN',
#   'Price': 'N/A',
#   'Processor': 'i7',
#   'Brand': 'LENOVO',
#   'RAM': '24GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': 'N/A',
#   'Screen Size': '15.3'},
#  {'Title': 'acer Aspire Go 14,14th Gen, Intel Core Ultra 5 125H, 16GB DDR5, 512GB, WUXGA IPS, 14.0"/35.56cm, Win 11, MS Office, Steel Gray, 1.5 kg, AG14-71M, Backlit KB, AI Powered Laptop',
#   'Price': '54,990',
#   'Processor': None,
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '3.6',
#   'Storage': '16GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(25% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Lenovo V14 Intel Core i5 13th Gen 14" FHD (1920x1080) Antiglare 250 Nits Thin and Light Laptop (16GB RAM/512GB SSD/Windows 11 Home/Office 2024/Iron Grey/1.43 kg), 83A0A0PTIN',
#   'Price': '53,650',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(40% off)',
#   'Screen Size': '14'},
#  {'Title': 'Lenovo IdeaPad Flex 5 AMD Ryzen 5 5625U (16GB RAM/512GB SSD/14 (35.5cm)/WUXGA IPS/Windows 11/Office Home 2024/Lenovo Digital Pen/1Yr ADP/Grey/1.5Kg), 82XX00G4IN Convertible Laptop',
#   'Price': '54,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(36% off)',
#   'Screen Size': '35.5'},
#  {'Title': 'Lenovo 14 (2025), Intel Core i5 13th Gen 13420H - (16 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Pro) Thin and Light Business Laptop/14.0" FHD Display/Iron Grey/1.4 kg/Microsoft Office 2021',
#   'Price': '53,700',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(46% off)',
#   'Screen Size': '14.0'},
#  {'Title': 'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)',
#   'Price': '22,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '8GB',
#   'Rating': '4.4',
#   'Storage': '8GB',
#   'Windows': 'N/A',
#   'Color': 'Gray',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Primebook 2 Neo 2025 (New Launch) | 6GB RAM, 128GB Storage (Upgradable Upto 512GB) | MediaTek Helio G99 | Android 15 (PrimeOS3.0) | in-Built AI | 11.6” Thin & Light Laptop | Type-C, USB, MicroSD Ports',
#   'Price': '15,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '6GB',
#   'Rating': '4.4',
#   'Storage': '6GB',
#   'Windows': 'N/A',
#   'Color': 'N/A',
#   'Discount': '(36% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '66,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop",
#   'Price': '60,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core 3, 14th Gen-100U, 8GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, Dell 15, Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '39,990',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15 Laptop, AMD Ryzen 5 7520U (16GB DDR5,512GB SSD) Win11,M365 Basic(1yr)*Office Home24, Anti-Glare,15.6''/39.6cm,FHD,Backlit KB,FHD Camera w/Privacy Shutter,Radeon Graphics, Silver,1.59kg FC0690AU",
#   'Price': '45,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(17% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Dell 15, Intel Core 3 14th Gen-100U, 16GB DDR4, 512GB SSD, FHD IPS, 15.6"/39.62cm, Win 11, Office H&S 2024, Carbon Black, 1.63Kg, [Dell 15], Intel UHD Graphics, 120Hz 250 nit, Thin & Light, Laptop',
#   'Price': '44,326',
#   'Processor': None,
#   'Brand': 'DELL',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(16% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'MSI Thin A15, Ryzen 5 7535HS, 40CM FHD 144Hz Gaming Laptop(16GB/512 GB NVMe SSD/Windows 11 Home/NVIDIA GeForce RTX 3050, GDDR6 4GB /Cosmos Gray/1.86Kg), B7UC-067IN',
#   'Price': '62,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'MSI',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(30% off)',
#   'Screen Size': '40'},
#  {'Title': 'acer Aspire Lite 12th Gen Intel Core i3-1215U Premium Metal Laptop (Windows 11 Home/16 GB RAM/512GB SSD) AL15-52, 39.62cm (15.6") Full HD Display, Metal Body, Steel Gray, 1.59 Kg',
#   'Price': '37,990',
#   'Processor': 'i3',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Gray',
#   'Discount': '(28% off)',
#   'Screen Size': '62'},
#  {'Title': 'HP Professional 14 (2025), Intel Core i3 13th Gen 1315U - (8 GB/512 GB SSD/Intel UHD Graphics/Windows 11 Home) Thin and Light Business Laptop/14.0" HD Display/Turbo Silver/1.4 Kg/MSO 2021',
#   'Price': 'N/A',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '3.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': 'N/A',
#   'Screen Size': '14.0'},
#  {'Title': 'ASUS Vivobook Go 15, 7000 Series, AMD Ryzen 3 7320U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Cool Silver, 1.63 kg, E1504FA-BQ2321WS, Laptop',
#   'Price': '34,680',
#   'Processor': 'Ryzen 3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook Go 15, AMD Ryzen 5 7520U Thin & Light Laptop(AMD Radeon iGPU/8GB RAM/512GB SSD/FHD/15.6"/60Hz/Windows 11/M365 Basic (1Year)*/Office Home 2024/Cool Silver/1.63 Kg) E1504FA-NJ132WS',
#   'Price': '37,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(25% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU",
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN',
#   'Price': '46,699',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP 15 255R G10, AMD Ryzen 5 7535U Hexa Core (6 Core, 12 Threads, 2.9 to Max 4.3 Ghz) (8 GB/512 GB SSD/AMD Radeon Graphics/Windows 11) Thin and Light Laptop(15.6 inch HD Display, Matt Silver, 1.45 kg',
#   'Price': '38,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'HP',
#   'RAM': 'N/A',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(13% off)',
#   'Screen Size': 'N/A'},
#  {'Title': "HP Victus, AMD Ryzen 7 7445HS, 6GB RTX 4050, 16GB DDR5(Upgradeable) 512GB SSD, 144Hz, IPS, 300nits, FHD, 15.6''/39.6cm, Win11, M365* Office24, Blue, 2.29kg, fb3130AX, Backlit, DTS Audio, Gaming Laptop",
#   'Price': '87,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(8% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP 15, AMD Ryzen 7 5825U (16GB DDR4, 512GB SSD) FHD, Anti-Glare, Micro-Edge,15.6''/39.6cm, Win11, M365(1yr)* Office24, Silver, 1.59kg, fc0476AU, Radeon Graphics, FHD Camera w/Shutter, Backlit Laptop",
#   'Price': '49,990',
#   'Processor': 'Ryzen 7',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(10% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 1, AMD Ryzen 5 5500U, 16GB RAM, 512GB SSD, HD, 15.6", Windows 11 Home, MS Office 21, Cloud Grey, 1.61Kg, 82R400ERIN, Integrated AMD Graphics, 1Yr ADP Free, Thin and Light Laptop',
#   'Price': '42,800',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(34% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo ThinkBook 16 AMD Ryzen 5 7535HS (8GB RAM/512GB SSD/Win 11 Home/Office 2024/Backlit Keyboard/Fingerprint) 16" WUXGA IPS 300 Nits Thin & Light Laptop/1Y Warranty/Aluminium Top/1.7kg, 21MWA0BRIN',
#   'Price': '46,990',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(37% off)',
#   'Screen Size': '16'},
#  {'Title': "HP Smartchoice OmniBook 5 (Previously Pavilion) 50 Tops, AMD Ryzen AI 5 340 (16GB LPDDR5X, 512GB SSD) WUXGA 2K, 16''/40.6cm, Win11, Office24, Silver, 1.79kg, ag1037au, Next Gen AI Copilot+ Laptop",
#   'Price': '68,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(21% off)',
#   'Screen Size': '16'},
#  {'Title': 'acer Professional 14[New Launch], 13th Gen Intel Core i7-1355U Turbo Boost, 32GB DDR4, 1TB SSD, Win11 Pro, MSO21, 14inch FHD Laptop, 3 Year Warranty, 1 Year Anti Virus, Fingerprint, Backlit KB',
#   'Price': '83,690',
#   'Processor': 'i7',
#   'Brand': 'ACER',
#   'RAM': '32GB',
#   'Rating': '4.1',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(7% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'acer Aspire 14, 13th Gen, Intel Core i5-13420H Processors, 16 GB RAM, 512 GB SSD, WUXGA IPS, 14"/35.56 cm, Windows 11 Home, MSO, Pure Silver, 1.44 kg, AS14H-53, Backlit KB, Thin and Light Laptop',
#   'Price': '57,990',
#   'Processor': 'i5',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': 'N/A',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(22% off)',
#   'Screen Size': '14'},
#  {'Title': 'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)',
#   'Price': '22,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '8GB',
#   'Rating': '4.4',
#   'Storage': '8GB',
#   'Windows': 'N/A',
#   'Color': 'Gray',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB RAM/512GB SSD/Integrated AMD Radeon Graphics/Windows 11/Office Home 2024/Grey/1.6Kg), 82XM0114IN',
#   'Price': '52,490',
#   'Processor': 'Ryzen 7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(28% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 5 OLED (Previously Pavilion), Snapdragon X Processor (16GB LPDDR5x, 512GB SSD) 2K, 14''/35.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.35kg, he0014QU, Light-Weight, Next-Gen AI Laptop",
#   'Price': '66,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(20% off)',
#   'Screen Size': '14'},
#  {'Title': "HP 15, 13th Gen Intel Core i5-13420H, (16GB DDR4, 512GB SSD), FHD, Anti-Glare, Micro-Edge, 15.6''/39.6cm, Win11, M365 Basic(1yr)* Office24, Silver, 1.65kg, FR0045TU, Camera w/Shutter, Backlit Laptop",
#   'Price': '60,490',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(12% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook 15, 13th Gen, Intel Core i3-1315U, 16GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Quiet Blue, 1.70 kg, X1504VA-BQ342WS, Laptop',
#   'Price': '40,990',
#   'Processor': 'i3',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(25% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo IdeaPad Slim 3, 13th Gen Intel Core i5 13420H, 24GB RAM, 1TB SSD, WUXGA IPS, 15.3"/38.8cm, Windows 11, Office Home 2024, Grey, 1.6Kg, Backlit Keyboard, 1Yr ADP Free, 83K100PLIN, Laptop',
#   'Price': '70,990',
#   'Processor': 'i5',
#   'Brand': 'LENOVO',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(19% off)',
#   'Screen Size': '15.3'},
#  {'Title': 'Lenovo Smartchoice Ideapad Slim 3, 13th Gen Intel Core i7 13620H, 16GB RAM, 512GB SSD, WUXGA IPS, 15.3"/38.8cm, Win 11, Office 2024, Top Metal Cover Grey, 1.6Kg, 83K100CJIN/S1IN, Backlit KB, Laptop',
#   'Price': '75,990',
#   'Processor': 'i7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.1',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(15% off)',
#   'Screen Size': '15.3'},
#  {'Title': 'Lenovo IdeaPad Slim 3, Intel Core i3 13th Gen 1315U, 8GB RAM, 512GB SSD, FHD 15.6"(39.6cm), Windows 11, Office 2024, Grey, 1.6Kg, 82X700G5IN, Alexa Built-in, 1Yr ADP Free, 3 Month Game Pass Laptop',
#   'Price': '38,490',
#   'Processor': 'i3',
#   'Brand': 'LENOVO',
#   'RAM': '8GB',
#   'Rating': '3.8',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(28% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11/MS Office,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty',
#   'Price': '32,999',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '8GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(58% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'acer Professional14[New Launch], AMD Ryzen5 7430U Turbo Boost, 16GB DDR4, 512GB SSD, Win11 Pro, MSO21, 3 Year Warranty, IPS 14" FHD HDR Laptop, Metal Body, Anti Virus',
#   'Price': '47,990',
#   'Processor': 'Ryzen5',
#   'Brand': 'ACER',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'N/A',
#   'Discount': '(22% off)',
#   'Screen Size': '14'},
#  {'Title': 'ASUS Vivobook Go 15, 7000 Series, AMD Ryzen 3 7320U, 8 GB RAM, 512GB SSD, FHD, Anti-Glare, 15.6", 39.6 cm, Windows 11 Home, M365 Basic(1yr)* Office24, Mixed Black, 1.63 kg, E1504FA-BQ2322WS, Laptop',
#   'Price': '38,990',
#   'Processor': 'Ryzen 3',
#   'Brand': 'ASUS',
#   'RAM': '8GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Black',
#   'Discount': '(11% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook 15, Intel Core i3 13th Gen 1315U, 12GB RAM, 512GB SSD, FHD 15.6", Windows 11, Office Home 2024, Cool Silver, 1.7Kg, X1504VA-BQ331WS, Intel UHD iGPU, Thin & Light, 42Whrs Laptop',
#   'Price': '41,990',
#   'Processor': 'i3',
#   'Brand': 'ASUS',
#   'RAM': '12GB',
#   'Rating': '4.2',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP OmniBook 3 AMD Ryzen AI 5 330 Next Gen AI Laptop, (24GB DDR5, 1TB SSD), Anti-Glare,15.6''/39.6cm FHD, Win11,Office24, Silver,1.7kg, FHD Camera with Shutter, Fingerprint Readon, Backlit KB fn0074AU",
#   'Price': '67,990',
#   'Processor': None,
#   'Brand': 'HP',
#   'RAM': '24GB',
#   'Rating': '4.3',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(19% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo Ideapad Slim 3 AMD Ryzen 5 7520U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11/Microsoft 365 Basic + Office Home 2024/Backlit Keyboard/Grey/1.6Kg), 82XQ00XDIN',
#   'Price': '46,699',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(21% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'ASUS Vivobook 15,13th Gen,Intel Core i7-13620H(Intel UHD iGPU/16GB RAM/1TB SSD/FHD/15.6"/60Hz/Backlit Keyboard/42Whr/Windows 11/M365 Basic (1Year)*/Office Home 2024/Quiet Blue/1.7 Kg)X1502VA-BQ1298WS',
#   'Price': '67,990',
#   'Processor': 'i7',
#   'Brand': 'ASUS',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '1TB',
#   'Windows': 'Windows 11',
#   'Color': 'Blue',
#   'Discount': '(23% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'HP 15s, 12th Gen Intel Core i3-1215U Laptop (8GB DDR4, 512GB SSD) Anti-Glare, 15.6"/39.6cm, FHD, Win 11, MS Office 21, Silver, 1.69kg, Intel UHD Graphics, HD Camera, Dual Speakers, fy5011TU',
#   'Price': '40,990',
#   'Processor': 'i3',
#   'Brand': 'HP',
#   'RAM': '8GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(18% off)',
#   'Screen Size': '15.6'},
#  {'Title': 'Lenovo V15 G4 AMD Athlon Silver 7120U Laptop 8GB LPDDR5 Ram, 512 GB SSD PCIe, Windows 11 Lifetime Validity,15.6" FHD Screen, AMD Radeon 610M, Silver, 1 Year Brand Warranty',
#   'Price': 'N/A',
#   'Processor': None,
#   'Brand': 'LENOVO',
#   'RAM': '8GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': 'N/A',
#   'Screen Size': '15.6'},
#  {'Title': 'Microsoft New Surface Pro 12" - Windows 11 Home Copilot+ PC - LCD PixelSense Touchscreen - Qualcomm Snapdragon X Plus (8 Core) - 16GB RAM - 256GB SSD - Platinum - EP2-27654',
#   'Price': '85,016',
#   'Processor': None,
#   'Brand': 'MICROSOFT',
#   'RAM': '16GB',
#   'Rating': '3.3',
#   'Storage': '256GB',
#   'Windows': 'Windows 11',
#   'Color': 'Platinum',
#   'Discount': '(10% off)',
#   'Screen Size': '12'},
#  {'Title': 'acer Aspire Lite, 12th gen, Intel Core i5-12450H Processor, 16 GB, 512GB, Full HD IPS, 15.6"/39.62 cm, Windows 11 Home, MSO, Pure Silver, 1.70 kg, AL15-52H, Backlit Keyboard',
#   'Price': '48,990',
#   'Processor': 'i5',
#   'Brand': 'ACER',
#   'RAM': 'N/A',
#   'Rating': '4.0',
#   'Storage': '16GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(27% off)',
#   'Screen Size': '15.6'},
#  {'Title': "HP Pavilion Plus, Intel Core i5-1335U-13th Gen Laptop, (16GB LPDDR5x,512GB SSD),IPS, 300 nits, 14''(35.6cm) 2K,Win 11, M365 Basic(1yr), Office Home 24, Silver,1.38kg, 5MP Camera w/Shutter, ew0107TU",
#   'Price': '61,990',
#   'Processor': 'i5',
#   'Brand': 'HP',
#   'RAM': '16GB',
#   'Rating': '3.6',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Silver',
#   'Discount': '(26% off)',
#   'Screen Size': '14'},
#  {'Title': 'Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD Laptop, AMD Graphics, 16GB DDR5 5500Mhz Ram, 512GB SSD NVMe, Windows 11, Dolby Audio, Arctic Grey, 1 Year Onsite Brand Warranty',
#   'Price': 'N/A',
#   'Processor': 'Ryzen 5',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '4.0',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': 'N/A',
#   'Screen Size': 'N/A'},
#  {'Title': 'Dyazo Slim 15" to 15.6 Inch Laptop Sleeve, Laptop Cover Case with Handle & Accessories Pocket Universal Compatible for Dell, HP, Lenovo, Asus and All Other Notebook etc. (Grey)',
#   'Price': '279',
#   'Processor': None,
#   'Brand': 'DYAZO',
#   'RAM': 'N/A',
#   'Rating': '4.3',
#   'Storage': 'N/A',
#   'Windows': 'N/A',
#   'Color': 'Grey',
#   'Discount': '(72% off)',
#   'Screen Size': '15'},
#  {'Title': 'Primebook 2 Max 2025 (New Launch) | 8GB RAM, 256GB UFS Storage | 15.6-Inch Full HD IPS Display | 12hrs Battery | MediaTek Helio G99 | Android 15 (PrimeOS 3.0) | Backlit Keyboard | in-Built AI (Gray)',
#   'Price': '22,990',
#   'Processor': None,
#   'Brand': 'PRIMEBOOK',
#   'RAM': '8GB',
#   'Rating': '4.4',
#   'Storage': '8GB',
#   'Windows': 'N/A',
#   'Color': 'Gray',
#   'Discount': '(34% off)',
#   'Screen Size': 'N/A'},
#  {'Title': 'Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39.6cm) FHD Thin and Light Laptop (16GB RAM/512GB SSD/Integrated AMD Radeon Graphics/Windows 11/Office Home 2024/Grey/1.6Kg), 82XM0114IN',
#   'Price': '52,490',
#   'Processor': 'Ryzen 7',
#   'Brand': 'LENOVO',
#   'RAM': '16GB',
#   'Rating': '3.9',
#   'Storage': '512GB',
#   'Windows': 'Windows 11',
#   'Color': 'Grey',
#   'Discount': '(28% off)',
#   'Screen Size': '15.6'}]

# %%
df=pd.DataFrame(data)
df
# Out:
#                                                  Title   Price Processor  \
# 0    HP Omnibook 5 OLED, Snapdragon X Processor (16...  69,990      None
# 1    HP 15, 13th Gen Intel Core i5-13420H, (16GB DD...  60,490        i5
# 2    EBook 11.6" HD Laptop | Best Student & Office ...  10,990      None
# 3    HP 15, AMD Ryzen 3 7320U (8GB DDR4, 512GB SSD)...     N/A   Ryzen 3
# 4    BrowseBook 14.1" FHD IPS Laptop | Best Student...  12,990      None
# ..                                                 ...     ...       ...
# 127  HP Pavilion Plus, Intel Core i5-1335U-13th Gen...  61,990        i5
# 128  Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD ...     N/A   Ryzen 5
# 129  Dyazo Slim 15" to 15.6 Inch Laptop Sleeve, Lap...     279      None
# 130  Primebook 2 Max 2025 (New Launch) | 8GB RAM, 2...  22,990      None
# 131  Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39....  52,490   Ryzen 7
#
#           Brand   RAM Rating Storage     Windows   Color   Discount  \
# 0            HP  16GB    4.1     1TB  Windows 11  Silver  (19% off)
# 1            HP  16GB    4.0   512GB  Windows 11  Silver  (12% off)
# 2         EBOOK   4GB    5.0     4GB  Windows 11   Black  (56% off)
# 3            HP   8GB    4.0   512GB  Windows 11  Silver        N/A
# 4    BROWSEBOOK   4GB    3.0   128GB  Windows 11    Grey  (57% off)
# ..          ...   ...    ...     ...         ...     ...        ...
# 127          HP  16GB    3.6   512GB  Windows 11  Silver  (26% off)
# 128      LENOVO  16GB    4.0   512GB  Windows 11    Grey        N/A
# 129       DYAZO   N/A    4.3     N/A         N/A    Grey  (72% off)
# 130   PRIMEBOOK   8GB    4.4     8GB         N/A    Gray  (34% off)
# 131      LENOVO  16GB    3.9   512GB  Windows 11    Grey  (28% off)
#
#     Screen Size
# 0            16
# 1          15.6
# 2          11.6
# 3          15.6
# 4          14.1
# ..          ...
# 127          14
# 128         N/A
# 129          15
# 130         N/A
# 131        15.6
#
# [132 rows x 11 columns]

# %%
df['Product Name'] = df['Title'].str.split(r'[|,]').str[0].str.strip()
col = df.pop('Product Name')
df.insert(0, 'Product Name', col)
df.drop("Title",axis=1,inplace=True)

# %%
df.to_csv("amazon_laptops_raw.csv")

# %%
df
# Out:
#                                           Product Name   Price Processor  \
# 0                                   HP Omnibook 5 OLED  69,990      None
# 1                                                HP 15  60,490        i5
# 2                                EBook 11.6" HD Laptop  10,990      None
# 3                                                HP 15     N/A   Ryzen 3
# 4                      BrowseBook 14.1" FHD IPS Laptop  12,990      None
# ..                                                 ...     ...       ...
# 127                                   HP Pavilion Plus  61,990        i5
# 128  Lenovo V15 G4 AMD Ryzen 5 7520U 15.6 inch FHD ...     N/A   Ryzen 5
# 129          Dyazo Slim 15" to 15.6 Inch Laptop Sleeve     279      None
# 130                  Primebook 2 Max 2025 (New Launch)  22,990      None
# 131  Lenovo IdeaPad Slim 3 Ryzen 7 5825U 15.6" (39....  52,490   Ryzen 7
#
#           Brand   RAM Rating Storage     Windows   Color   Discount  \
# 0            HP  16GB    4.1     1TB  Windows 11  Silver  (19% off)
# 1            HP  16GB    4.0   512GB  Windows 11  Silver  (12% off)
# 2         EBOOK   4GB    5.0     4GB  Windows 11   Black  (56% off)
# 3            HP   8GB    4.0   512GB  Windows 11  Silver        N/A
# 4    BROWSEBOOK   4GB    3.0   128GB  Windows 11    Grey  (57% off)
# ..          ...   ...    ...     ...         ...     ...        ...
# 127          HP  16GB    3.6   512GB  Windows 11  Silver  (26% off)
# 128      LENOVO  16GB    4.0   512GB  Windows 11    Grey        N/A
# 129       DYAZO   N/A    4.3     N/A         N/A    Grey  (72% off)
# 130   PRIMEBOOK   8GB    4.4     8GB         N/A    Gray  (34% off)
# 131      LENOVO  16GB    3.9   512GB  Windows 11    Grey  (28% off)
#
#     Screen Size
# 0            16
# 1          15.6
# 2          11.6
# 3          15.6
# 4          14.1
# ..          ...
# 127          14
# 128         N/A
# 129          15
# 130         N/A
# 131        15.6
#
# [132 rows x 11 columns]
